# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubhaminferenz/gantts/blob/master/gantts_indianaccentold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/yanggeng1995/GAN-TTS
# Out:
# Cloning into 'GAN-TTS'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 123 (delta 50), reused 67 (delta 14), pack-reused 0
# Receiving objects: 100% (123/123), 4.47 MiB | 8.85 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
cd GAN-TTS/
# Out:
# /content/GAN-TTS

# %%
# %pwd
# Out:
# '/content/GAN-TTS'

# %%
# !python process.py --wav_dir="wavs" --output="data"
# Out:
#   6% 73/1132 [00:11<03:00,  5.87it/s]Traceback (most recent call last):
#   File "process.py", line 89, in <module>
#     main()
#   File "process.py", line 86, in main
#     preprocess(args)
#   File "process.py", line 68, in preprocess
#   File "process.py", line 54, in process
#     return [result.result() for result in tqdm(results)]
#   File "process.py", line 54, in <listcomp>
#     return [result.result() for result in tqdm(results)]
#   File "/usr/lib/python3.6/concurrent/futures/_base.py", line 427, in result
#     self._condition.wait(timeout)
#   File "/usr/lib/python3.6/threading.py", line 295, in wait
#     waiter.acquire()
# KeyboardInterrupt
#   6% 73/1132 [02:43<39:33,  2.24s/it]

# %%
# !pip install tensorboardx

# %%
# !python train.py --input='data/train'
# Out:
# Streaming output truncated to the last 5000 lines.
# Step: 15304 --sc_loss: 0.220 --mag_loss: 0.451 --Time: 1.24 seconds
# Step: 15305 --sc_loss: 0.182 --mag_loss: 0.449 --Time: 1.23 seconds
# Step: 15306 --sc_loss: 0.200 --mag_loss: 0.452 --Time: 1.23 seconds
# Step: 15307 --sc_loss: 0.192 --mag_loss: 0.443 --Time: 1.22 seconds
# Step: 15308 --sc_loss: 0.228 --mag_loss: 0.450 --Time: 1.21 seconds
# Step: 15309 --sc_loss: 0.214 --mag_loss: 0.450 --Time: 1.22 seconds
# Step: 15310 --sc_loss: 0.212 --mag_loss: 0.443 --Time: 1.22 seconds
# Step: 15311 --sc_loss: 0.206 --mag_loss: 0.443 --Time: 1.21 seconds
# Step: 15312 --sc_loss: 0.205 --mag_loss: 0.453 --Time: 1.24 seconds
# Step: 15313 --sc_loss: 0.195 --mag_loss: 0.485 --Time: 0.87 seconds
# Step: 15314 --sc_loss: 0.195 --mag_loss: 0.444 --Time: 1.33 seconds
# Step: 15315 --sc_loss: 0.229 --mag_loss: 0.441 --Time: 1.23 seconds
# Step: 15316 --sc_loss: 0.203 --mag_loss: 0.450 --Time: 1.24 seconds
# ...

# %%
# !python generate.py --input="data/test"
# Out:
# Restore from logdir/model.ckpt-20000.pt
# (85200,)
# Time used: 3.483, RTF: 0.9812
# (66240,)
# Time used: 2.546, RTF: 0.9223
# Average RTF: 0.952
